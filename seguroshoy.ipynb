# %%
#Jupyter notebook for the generation of the data for the project seguroporhoy. Created by Javier Epeloa 15/04/2020
#Mapplics

# %%
import pandas as pd
data = pd.read_excel("seguroporhoy.xlsx", sheet_name="infoauto") #upload the file
data['Marca'] = data['Marca'].str.lstrip() #elimino espacios en blanco al principio
data['Modelo'] = data['Modelo'].str.lstrip() #elimino espacios en blanco al principio
filtro=pd.read_excel("Filtrados_info.xlsx")
data=data[~data['Código'].isin(filtro['Code'])]

# %%
data.head() #head the data to see if was propely upload
# Out:
#    Código  Marca               Modelo Impor  2020  2019  2018  2017  2016  \
# 0   10001  ACURA        INTEGRA LS SM    SI     0     0     0     0     0
# 1   10003  ACURA        INTEGRA RS SM    SI     0     0     0     0     0
# 2   10002  ACURA  INTEGRA RS SM COUPE    SI     0     0     0     0     0
# 3   10004  ACURA           INTEGRA SE    SI     0     0     0     0     0
# 4   10005  ACURA           LEGEND  GS    SI     0     0     0     0     0
#
#    2015  ...  Carga  Pesot  Veloc  Poten  Direc  Airea  Tracc  CajaV  Frabs  \
# 0     0  ...      N   1230    210    142    ASI     SI    DEL    MAN     NO
# 1     0  ...      N   1230    180    142    ASI     SI    DEL    MAN     NO
# 2     0  ...      N   1170    175    142    ASI     SI    DEL    MAN     NO
# 3     0  ...      N   1150    210    180    ASI     SI    DEL    MAN     NO
# 4     0  ...      N   1635    220    205    ASI     SI    DEL    MAN     NO
#
#    Airba
# 0     NO
# 1     NO
# 2     NO
# 3     NO
# 4     NO
#
# [5 rows x 50 columns]

# %%
def models(x):
    x = x.split(' ')[0]  #create a function to extract from the models data the first word separeted by a space
    if x=="":
        x="-"
    return x

# %%
def models_specification(x):
    x = " ".join(x.split()[1:-1])
    if x=="":
        x="-"
    return(x)

# %%
#data_agrupada=data
data['mod_abreviados']=data['Modelo'].apply(models) #generate the pandas column "mod abreviados" with th information of the models
data['Modelo']=data['Modelo'].apply(models_specification)

# %%
data_agrupada=data.groupby(['Marca','Modelo','mod_abreviados']).sum().reset_index() #here group the data to obtain the sum of the values of the year with the objetive of filter bellow
data_agrupada=data_agrupada.drop('Código', 1)
data.head()
# Out:
#    Código  Marca Modelo Impor  2020  2019  2018  2017  2016  2015  ...  Pesot  \
# 0   10001  ACURA     LS    SI     0     0     0     0     0     0  ...   1230
# 1   10003  ACURA     RS    SI     0     0     0     0     0     0  ...   1230
# 2   10002  ACURA  RS SM    SI     0     0     0     0     0     0  ...   1170
# 3   10004  ACURA      -    SI     0     0     0     0     0     0  ...   1150
# 4   10005  ACURA      -    SI     0     0     0     0     0     0  ...   1635
#
#    Veloc  Poten  Direc  Airea  Tracc  CajaV  Frabs  Airba  mod_abreviados
# 0    210    142    ASI     SI    DEL    MAN     NO     NO         INTEGRA
# 1    180    142    ASI     SI    DEL    MAN     NO     NO         INTEGRA
# 2    175    142    ASI     SI    DEL    MAN     NO     NO         INTEGRA
# 3    210    180    ASI     SI    DEL    MAN     NO     NO         INTEGRA
# 4    220    205    ASI     SI    DEL    MAN     NO     NO          LEGEND
#
# [5 rows x 51 columns]

# %%
data_agrupada.head(10000) #head the data
# Out:
#        Marca   Modelo mod_abreviados  2020  2019  2018  2017  2016  2015  \
# 0      ACURA        -        INTEGRA     0     0     0     0     0     0
# 1      ACURA        -         LEGEND     0     0     0     0     0     0
# 2      ACURA        -            NSX     0     0     0     0     0     0
# 3      ACURA        L         LEGEND     0     0     0     0     0     0
# 4      ACURA       LS        INTEGRA     0     0     0     0     0     0
# ...      ...      ...            ...   ...   ...   ...   ...   ...   ...
# 7137  YUEJIN       NJ         CAMION     0     0     0     0     0     0
# 7138  YUEJIN  NJ 1026         CAMION     0     0     0     0     0     0
# 7139  YUEJIN  NJ 1030         CAMION     0     0     0     0     0     0
# 7140  YUEJIN  NJ 1062         CAMION     0     0     0     0     0     0
# 7141  YUEJIN  NJ 3062         CAMION     0     0     0     0     0     0
#
#       2014  ...  1996  1995  1994  1993  1992  1991  Motor  Pesot  Veloc  \
# 0        0  ...   169   167   165   163   161     0    1.8   1150    210
# 1        0  ...   228   226   224   222   220   218    3.2   1635    220
# 2        0  ...     0     0     0     0     0     0    3.0      0      0
# 3        0  ...   243   241   239   237   235   233    3.2   1545    226
# 4        0  ...   164   162   160   158   156     0    1.8   1230    210
# ...    ...  ...   ...   ...   ...   ...   ...   ...    ...    ...    ...
# 7137     0  ...     0     0     0     0     0     0    0.0   7800    300
# 7138     0  ...     0     0     0     0     0     0    0.0   5200    200
# 7139     0  ...     0     0     0     0     0     0    0.0   2600    100
# 7140     0  ...     0     0     0     0     0     0    0.0   2600    100
# 7141     0  ...     0     0     0     0     0     0    0.0   2600    100
#
#       Poten
# 0       180
# 1       205
# 2         0
# 3       205
# 4       142
# ...     ...
# 7137    360
# 7138    240
# 7139    120
# 7140    120
# 7141    120
#
# [7142 rows x 37 columns]

# %%
tabla=data_agrupada.melt(id_vars=["Marca", "Modelo","mod_abreviados"], 
        value_vars=[2020,2019,2018,2017,2016,2015,2014,2013,2012,2011,2010,2009,2008,2007,2006,2005,2004,2003,2002,2001,2000,1999,1998,1997,1996,1995,1994,1993,1992,1991]
                        )   #in this line the data is transformed to put the yers from columns to rows

# %%
validos=tabla[tabla['value']>0]  #filter the data that are not zero

# %%
validos.head()
# Out:
#         Marca                       Modelo mod_abreviados variable  value
# 14295  AGRALE                            -          10000     2018   1760
# 14457    AUDI                        1.4 T             Q3     2018   2400
# 14458    AUDI                  1.4 T 150HP             Q3     2018   2450
# 14459    AUDI  1.4 T 150HP STRONIC OFFROAD             Q2     2018   2400
# 14460    AUDI                         1.4T             A1     2018   1510

# %%
validos_agrupados=validos.groupby(['Marca','mod_abreviados','variable']).Modelo.apply(lambda x: ','.join(map(str, x))).reset_index()
validos_agrupados.head() #group the models, separate the data by,','
# Out:
#    Marca mod_abreviados  variable         Modelo
# 0  ACURA        INTEGRA      1992  -,LS,RS,RS SM
# 1  ACURA        INTEGRA      1993  -,LS,RS,RS SM
# 2  ACURA        INTEGRA      1994  -,LS,RS,RS SM
# 3  ACURA        INTEGRA      1995  -,LS,RS,RS SM
# 4  ACURA        INTEGRA      1996  -,LS,RS,RS SM

# %%
validos_agrupados=validos_agrupados.groupby(['Marca','Modelo','mod_abreviados']).variable.apply(lambda x: ','.join(map(str, x))).reset_index()
validos_agrupados.head() #group the years, separate the data by ','
# Out:
#     Marca                                        Modelo mod_abreviados  \
# 0   ACURA                                        -,L,LS         LEGEND
# 1   ACURA                                 -,LS,RS,RS SM        INTEGRA
# 2  AEOLUS                 1061 G8 D2 (DONG,1061 T (DONG             EQ
# 3  AEOLUS  1061 G8 D2 (DONG,1061 T (DONG,1061 T5D (DONG             EQ
# 4  AEOLUS                                  1061 T (DONG             EQ
#
#                              variable
# 0  1991,1992,1993,1994,1995,1996,1997
# 1       1992,1993,1994,1995,1996,1997
# 2                                1999
# 3                           2000,2001
# 4                                1998

# %%
validos_agrupados.columns = ['Marca', 'Modelos', 'mod_abreviados', 'Años_disponibles'] #change the names of the columns

# %%
validos_agrupados.head()
# Out:
#     Marca                                       Modelos mod_abreviados  \
# 0   ACURA                                        -,L,LS         LEGEND
# 1   ACURA                                 -,LS,RS,RS SM        INTEGRA
# 2  AEOLUS                 1061 G8 D2 (DONG,1061 T (DONG             EQ
# 3  AEOLUS  1061 G8 D2 (DONG,1061 T (DONG,1061 T5D (DONG             EQ
# 4  AEOLUS                                  1061 T (DONG             EQ
#
#                      Años_disponibles
# 0  1991,1992,1993,1994,1995,1996,1997
# 1       1992,1993,1994,1995,1996,1997
# 2                                1999
# 3                           2000,2001
# 4                                1998

# %%
validos_agrupados=validos_agrupados.groupby(['Marca'], as_index = False).agg({'Modelos': (lambda x: ','.join(map(str, x))), 'mod_abreviados': (lambda x: ','.join(map(str, x))),'Años_disponibles': (lambda x: ','.join(map(str, x)))})
validos_agrupados.head() #finally group only the Marca tag, concatenated the Marca, Modelo and mod_abreviado separated by ','
# Out:
#         Marca                                            Modelos  \
# 0       ACURA                               -,L,LS,-,LS,RS,RS SM
# 1      AEOLUS  1061 G8 D2 (DONG,1061 T (DONG,1061 G8 D2 (DONG...
# 2      AGRALE  -,-,-,-,-,-,AM100,AM150,-,CHASIS,-,RD DOBLE,-,...
# 3       ALEKO                                         -,D,D PICK
# 4  ALFA ROMEO  -,-,-,-,1.4,1.7,1.7 SPORT,1.7 SPORT WAGON,-,1....
#
#                                       mod_abreviados  \
# 0                                     LEGEND,INTEGRA
# 1                                        EQ,EQ,EQ,EQ
# 2  10000,13000,6000,8500,9200,MARRUA,DYNAMIC,6000...
# 3                                          2141,2335
# 4  145,SPIDER,ZAGATO,33,33,33,145,SPIDER,MITO,MIT...
#
#                                     Años_disponibles
# 0  1991,1992,1993,1994,1995,1996,1997,1992,1993,1...
# 1                           1999,2000,2001,1998,2002
# 2  2016,2017,2018,2008,2009,2010,2011,2012,2013,2...
# 3  1993,1994,1995,1996,1997,1993,1994,1995,1996,1997
# 4  1994,1995,1991,1992,1993,1994,1995,1993,1994,1...

# %%
def duplicates(x):
    x = ','.join(set(x.split(',')))
    return x    #create a funtion to delete the duplicates in the lists of the columns

# %%
def sort_models(x):
    arr = x.split(',')
    arr = sorted(arr, key=str,reverse=True)
    return ','.join(str(i) for i in arr)
    return x    #create a funtion to delete the duplicates in the lists of the columns

# %%
validos_agrupados['Años_disponibles']=validos_agrupados['Años_disponibles'].apply(duplicates)
validos_agrupados['mod_abreviados']=validos_agrupados['mod_abreviados'].apply(duplicates)
validos_agrupados['Modelos']=validos_agrupados['Modelos'].apply(duplicates)
validos_agrupados['Suma']=0
validos_agrupados.head()    #apply the duplicates funtion on the columns "Años disponible", "mod_Abreviados", "Modelos"
# Out:
#         Marca                                            Modelos  \
# 0       ACURA                                    LS,RS SM,-,L,RS
# 1      AEOLUS       1061 T5D (DONG,1061 T (DONG,1061 G8 D2 (DONG
# 2      AGRALE  TCE,AM150,CHASIS LARGO,RD E-MEC,-,AM100,RD DOB...
# 3       ALEKO                                         D,-,D PICK
# 4  ALFA ROMEO  2.5 V6 FASE,1.7 SPORT WAGON,3.0 V6 12V,1.8 TS,...
#
#                                       mod_abreviados  \
# 0                                     LEGEND,INTEGRA
# 1                                                 EQ
# 2  7500,8500,9200,6000,STALLION,10000,STARK,MARRU...
# 3                                          2335,2141
# 4  155,GT,MITO,166,159,33,ZAGATO,GIULIETTA,BRERA,...
#
#                                     Años_disponibles  Suma
# 0                 1997,1992,1991,1993,1994,1996,1995     0
# 1                           2002,2001,1998,1999,2000     0
# 2  2016,1993,1999,1996,2007,1998,2006,2017,2000,1...     0
# 3                           1997,1993,1994,1996,1995     0
# 4  1992,2016,2003,1993,1999,1996,2007,1998,2004,2...     0

# %%
validos_agrupados['mod_abreviados']=validos_agrupados['mod_abreviados'].apply(sort_models)
validos_agrupados['Años_disponibles']=validos_agrupados['Años_disponibles'].apply(sort_models)
validos_agrupados['Modelos']=validos_agrupados['Modelos'].apply(sort_models)
validos_agrupados.head()
# Out:
#         Marca                                            Modelos  \
# 0       ACURA                                    RS SM,RS,LS,L,-
# 1      AEOLUS       1061 T5D (DONG,1061 T (DONG,1061 G8 D2 (DONG
# 2      AGRALE  TCE,RD E-MEC,RD DOBLE,RD,CHASIS LARGO,CHASIS C...
# 3       ALEKO                                         D PICK,D,-
# 4  ALFA ROMEO  3.2 MD 4X4,3.2 JTS HIGHT 4X4 ELEGANTE,3.2 JTS,...
#
#                                       mod_abreviados  \
# 0                                     LEGEND,INTEGRA
# 1                                                 EQ
# 2  STARK,STALLION,MARRUA,DYNAMIC,9200,8500,7500,6...
# 3                                          2335,2141
# 4  ZAGATO,SPIDER,MITO,GTV,GT,GIULIETTA,BRERA,33,1...
#
#                                     Años_disponibles  Suma
# 0                 1997,1996,1995,1994,1993,1992,1991     0
# 1                           2002,2001,2000,1999,1998     0
# 2  2018,2017,2016,2015,2014,2013,2012,2011,2010,2...     0
# 3                           1997,1996,1995,1994,1993     0
# 4  2017,2016,2015,2014,2013,2012,2011,2010,2009,2...     0

# %%
matriz_propiedad_excel = pd.DataFrame()   #definition of the final propiety table
matriz_propiedad_excel['Código Info']=0
matriz_propiedad_excel['Type']='variable'
matriz_propiedad_excel['SKU']=0
matriz_propiedad_excel['Name']=validos_agrupados['Marca']
matriz_propiedad_excel['Categories']='30 garage,7 garage'  
matriz_propiedad_excel['Parent']=0
matriz_propiedad_excel['Attribute 1 name']='anio'
matriz_propiedad_excel['Attribute 1 value(s)']=validos_agrupados['Años_disponibles']
matriz_propiedad_excel['Attribute 2 name']='Modelo'
matriz_propiedad_excel['Attribute 2 value(s)']=validos_agrupados['mod_abreviados']
matriz_propiedad_excel['Attribute 3 name']='Versión'
matriz_propiedad_excel['Attribute 3 value(s)']=validos_agrupados['Modelos']
matriz_propiedad_excel['Regular price']=0
matriz_propiedad_excel['Sale price']=0
matriz_propiedad_excel['In stock?']=1
matriz_propiedad_excel['Published']=1
matriz_propiedad_excel['Visibility in catalog']='visible'
matriz_propiedad_excel['Suma']=0
matriz_propiedad_excel.head()
# Out:
#    Código Info Type  SKU        Name          Categories  Parent  \
# 0          NaN  NaN  NaN       ACURA  30 garage,7 garage       0
# 1          NaN  NaN  NaN      AEOLUS  30 garage,7 garage       0
# 2          NaN  NaN  NaN      AGRALE  30 garage,7 garage       0
# 3          NaN  NaN  NaN       ALEKO  30 garage,7 garage       0
# 4          NaN  NaN  NaN  ALFA ROMEO  30 garage,7 garage       0
#
#   Attribute 1 name                               Attribute 1 value(s)  \
# 0             anio                 1997,1996,1995,1994,1993,1992,1991
# 1             anio                           2002,2001,2000,1999,1998
# 2             anio  2018,2017,2016,2015,2014,2013,2012,2011,2010,2...
# 3             anio                           1997,1996,1995,1994,1993
# 4             anio  2017,2016,2015,2014,2013,2012,2011,2010,2009,2...
#
#   Attribute 2 name                               Attribute 2 value(s)  \
# 0           Modelo                                     LEGEND,INTEGRA
# 1           Modelo                                                 EQ
# 2           Modelo  STARK,STALLION,MARRUA,DYNAMIC,9200,8500,7500,6...
# 3           Modelo                                          2335,2141
# 4           Modelo  ZAGATO,SPIDER,MITO,GTV,GT,GIULIETTA,BRERA,33,1...
#
#   Attribute 3 name                               Attribute 3 value(s)  \
# 0          Versión                                    RS SM,RS,LS,L,-
# 1          Versión       1061 T5D (DONG,1061 T (DONG,1061 G8 D2 (DONG
# 2          Versión  TCE,RD E-MEC,RD DOBLE,RD,CHASIS LARGO,CHASIS C...
# 3          Versión                                         D PICK,D,-
# 4          Versión  3.2 MD 4X4,3.2 JTS HIGHT 4X4 ELEGANTE,3.2 JTS,...
#
#    Regular price  Sale price  In stock?  Published Visibility in catalog  Suma
# 0              0           0          1          1               visible     0
# 1              0           0          1          1               visible     0
# 2              0           0          1          1               visible     0
# 3              0           0          1          1               visible     0
# 4              0           0          1          1               visible     0

# %%
matriz_propiedad_excel['SKU']=matriz_propiedad_excel.index+100 #generate a definition of the SKU that start after 100
matriz_propiedad_excel['Type']='variable'
matriz_propiedad_excel.head()
# Out:
#    Código Info      Type  SKU        Name          Categories  Parent  \
# 0          NaN  variable  100       ACURA  30 garage,7 garage       0
# 1          NaN  variable  101      AEOLUS  30 garage,7 garage       0
# 2          NaN  variable  102      AGRALE  30 garage,7 garage       0
# 3          NaN  variable  103       ALEKO  30 garage,7 garage       0
# 4          NaN  variable  104  ALFA ROMEO  30 garage,7 garage       0
#
#   Attribute 1 name                               Attribute 1 value(s)  \
# 0             anio                 1997,1996,1995,1994,1993,1992,1991
# 1             anio                           2002,2001,2000,1999,1998
# 2             anio  2018,2017,2016,2015,2014,2013,2012,2011,2010,2...
# 3             anio                           1997,1996,1995,1994,1993
# 4             anio  2017,2016,2015,2014,2013,2012,2011,2010,2009,2...
#
#   Attribute 2 name                               Attribute 2 value(s)  \
# 0           Modelo                                     LEGEND,INTEGRA
# 1           Modelo                                                 EQ
# 2           Modelo  STARK,STALLION,MARRUA,DYNAMIC,9200,8500,7500,6...
# 3           Modelo                                          2335,2141
# 4           Modelo  ZAGATO,SPIDER,MITO,GTV,GT,GIULIETTA,BRERA,33,1...
#
#   Attribute 3 name                               Attribute 3 value(s)  \
# 0          Versión                                    RS SM,RS,LS,L,-
# 1          Versión       1061 T5D (DONG,1061 T (DONG,1061 G8 D2 (DONG
# 2          Versión  TCE,RD E-MEC,RD DOBLE,RD,CHASIS LARGO,CHASIS C...
# 3          Versión                                         D PICK,D,-
# 4          Versión  3.2 MD 4X4,3.2 JTS HIGHT 4X4 ELEGANTE,3.2 JTS,...
#
#    Regular price  Sale price  In stock?  Published Visibility in catalog  Suma
# 0              0           0          1          1               visible     0
# 1              0           0          1          1               visible     0
# 2              0           0          1          1               visible     0
# 3              0           0          1          1               visible     0
# 4              0           0          1          1               visible     0

# %%
##Esta sitabla=data_agrupada.melt(id_vars=["Marca", "Modelo"], 
datos=data.groupby(['Código','Marca','Modelo','mod_abreviados']).sum().reset_index()
matriz_costo=datos.melt(id_vars=["Código", "Marca", "Modelo", 'mod_abreviados'], 
        value_vars=[2020,2019,2018,2017,2016,2015,2014,2013,2012,2011,2010,2009,2008,2007,2006,2005,2004,2003,2002,2001,2000,1999,1998,1997,1996,1995,1994,1993,1992,1991]
                        )

# %%
matriz_costo.head()
# Out:
#    Código  Marca Modelo mod_abreviados variable  value
# 0   10001  ACURA     LS        INTEGRA     2020      0
# 1   10002  ACURA  RS SM        INTEGRA     2020      0
# 2   10003  ACURA     RS        INTEGRA     2020      0
# 3   10004  ACURA      -        INTEGRA     2020      0
# 4   10005  ACURA      -         LEGEND     2020      0

# %%
matriz_costo=matriz_costo[matriz_costo['value']>0]

# %%
def parents_id(x):
    x = matriz_propiedad_excel.loc[matriz_propiedad_excel.Name == x,'SKU'].tolist()
    s = ''.join(map(str, x))
    s=int(s)
    return(s)

# %%
matriz_costo.columns = ['Código', 'Marca','Modelo','mod_abreviados','Años_Disponibles','Suma']
##Aca armo la matriz con el valor final de lo que va a ir
matriz_costo_excel = pd.DataFrame()
matriz_costo_excel['Código Info']=matriz_costo['Código']
matriz_costo_excel['Type']='variation'
matriz_costo_excel['SKU']=matriz_costo['Código'].map(str) + "-" + matriz_costo['Años_Disponibles'].map(str)+ "-30"
matriz_costo_excel['Name']=matriz_costo['Marca']
matriz_costo_excel['Categories']='30 garage'
matriz_costo_excel['Parent']=matriz_costo['Marca'].apply(parents_id)
matriz_costo_excel['Attribute 1 name']='anio'
matriz_costo_excel['Attribute 1 value(s)']=matriz_costo['Años_Disponibles'].astype(str)
matriz_costo_excel['Attribute 2 name']='Modelo'
matriz_costo_excel['Attribute 2 value(s)']=matriz_costo['mod_abreviados']
matriz_costo_excel['Attribute 3 name']='Versión'
matriz_costo_excel['Attribute 3 value(s)']=matriz_costo['Modelo']
matriz_costo_excel['Regular price']=int(0)
matriz_costo_excel['Sale price']=int(0)
matriz_costo_excel['In stock?']=1
matriz_costo_excel['Published']=1
matriz_costo_excel['Visibility in catalog']='visible'
matriz_costo_excel['Suma']=matriz_costo['Suma']

# %%
matriz_costo_excel.head()
# Out:
#        Código Info       Type            SKU  Name Categories  Parent  \
# 19418        60387  variation  60387-2018-30  AUDI  30 garage     108
# 19501        60481  variation  60481-2018-30  AUDI  30 garage     108
# 19502        60482  variation  60482-2018-30  AUDI  30 garage     108
# 19504        60484  variation  60484-2018-30  AUDI  30 garage     108
# 19509        60527  variation  60527-2018-30  AUDI  30 garage     108
#
#       Attribute 1 name Attribute 1 value(s) Attribute 2 name  \
# 19418             anio                 2018           Modelo
# 19501             anio                 2018           Modelo
# 19502             anio                 2018           Modelo
# 19504             anio                 2018           Modelo
# 19509             anio                 2018           Modelo
#
#       Attribute 2 value(s) Attribute 3 name         Attribute 3 value(s)  \
# 19418                   A1          Versión                         1.4T
# 19501                   Q3          Versión                        1.4 T
# 19502                   Q3          Versión                  1.4 T 150HP
# 19504                   A4          Versión                   2.0 T L/16
# 19509                   Q2          Versión  1.4 T 150HP STRONIC OFFROAD
#
#        Regular price  Sale price  In stock?  Published Visibility in catalog  \
# 19418              0           0          1          1               visible
# 19501              0           0          1          1               visible
# 19502              0           0          1          1               visible
# 19504              0           0          1          1               visible
# 19509              0           0          1          1               visible
#
#        Suma
# 19418  1510
# 19501  2400
# 19502  2450
# 19504  2600
# 19509  2400

# %%
matriz_costo_excel1 = pd.DataFrame()
matriz_costo_excel1['Código Info']=matriz_costo['Código']
matriz_costo_excel1['Type']='variation'
matriz_costo_excel1['SKU']=matriz_costo['Código'].map(str) + "-" + matriz_costo['Años_Disponibles'].map(str)+ "-7"
matriz_costo_excel1['Name']=matriz_costo['Marca']
matriz_costo_excel1['Categories']='7 garage'
matriz_costo_excel1['Parent']=matriz_costo['Marca'].apply(parents_id)
matriz_costo_excel1['Attribute 1 name']='anio'
matriz_costo_excel1['Attribute 1 value(s)']=matriz_costo['Años_Disponibles'].astype(str)
matriz_costo_excel1['Attribute 2 name']='Modelo'
matriz_costo_excel1['Attribute 2 value(s)']=matriz_costo['mod_abreviados']
matriz_costo_excel1['Attribute 3 name']='Versión'
matriz_costo_excel1['Attribute 3 value(s)']=matriz_costo['Modelo']
matriz_costo_excel1['Regular price']=0
matriz_costo_excel1['Sale price']=0
matriz_costo_excel1['In stock?']=1
matriz_costo_excel1['Published']=1
matriz_costo_excel1['Visibility in catalog']='visible'
matriz_costo_excel1['Suma']=matriz_costo['Suma']

# %%
matriz_costo_excel1.head()
# Out:
#        Código Info       Type           SKU  Name Categories  Parent  \
# 19418        60387  variation  60387-2018-7  AUDI   7 garage     108
# 19501        60481  variation  60481-2018-7  AUDI   7 garage     108
# 19502        60482  variation  60482-2018-7  AUDI   7 garage     108
# 19504        60484  variation  60484-2018-7  AUDI   7 garage     108
# 19509        60527  variation  60527-2018-7  AUDI   7 garage     108
#
#       Attribute 1 name Attribute 1 value(s) Attribute 2 name  \
# 19418             anio                 2018           Modelo
# 19501             anio                 2018           Modelo
# 19502             anio                 2018           Modelo
# 19504             anio                 2018           Modelo
# 19509             anio                 2018           Modelo
#
#       Attribute 2 value(s) Attribute 3 name         Attribute 3 value(s)  \
# 19418                   A1          Versión                         1.4T
# 19501                   Q3          Versión                        1.4 T
# 19502                   Q3          Versión                  1.4 T 150HP
# 19504                   A4          Versión                   2.0 T L/16
# 19509                   Q2          Versión  1.4 T 150HP STRONIC OFFROAD
#
#        Regular price  Sale price  In stock?  Published Visibility in catalog  \
# 19418              0           0          1          1               visible
# 19501              0           0          1          1               visible
# 19502              0           0          1          1               visible
# 19504              0           0          1          1               visible
# 19509              0           0          1          1               visible
#
#        Suma
# 19418  1510
# 19501  2400
# 19502  2450
# 19504  2600
# 19509  2400

# %%
frames = [matriz_costo_excel, matriz_costo_excel1]
final_costo=pd.concat(frames).sort_index().reset_index(drop=True)
#final_costo.sort_values('Name')
final_costo.head(30)
# Out:
#     Código Info       Type             SKU     Name Categories  Parent  \
# 0         60387  variation   60387-2018-30     AUDI  30 garage     108
# 1         60387  variation    60387-2018-7     AUDI   7 garage     108
# 2         60481  variation    60481-2018-7     AUDI   7 garage     108
# 3         60481  variation   60481-2018-30     AUDI  30 garage     108
# 4         60482  variation   60482-2018-30     AUDI  30 garage     108
# 5         60482  variation    60482-2018-7     AUDI   7 garage     108
# 6         60484  variation   60484-2018-30     AUDI  30 garage     108
# 7         60484  variation    60484-2018-7     AUDI   7 garage     108
# 8         60527  variation   60527-2018-30     AUDI  30 garage     108
# 9         60527  variation    60527-2018-7     AUDI   7 garage     108
# 10        80284  variation    80284-2018-7      BMW   7 garage     113
# 11        80284  variation   80284-2018-30      BMW  30 garage     113
# 12       110276  variation   110276-2018-7  CITROEN   7 garage     118
# 13       110276  variation  110276-2018-30  CITROEN  30 garage     118
# 14       110285  variation   110285-2018-7  CITROEN   7 garage     118
# 15       110285  variation  110285-2018-30  CITROEN  30 garage     118
# 16       110294  variation   110294-2018-7  CITROEN   7 garage     118
# 17       110294  variation  110294-2018-30  CITROEN  30 garage     118
# 18       110303  variation   110303-2018-7  CITROEN   7 garage     118
# 19       110303  variation  110303-2018-30  CITROEN  30 garage     118
# 20       110304  variation   110304-2018-7  CITROEN   7 garage     118
# 21       110304  variation  110304-2018-30  CITROEN  30 garage     118
# 22       110305  variation   110305-2018-7  CITROEN   7 garage     118
# 23       110305  variation  110305-2018-30  CITROEN  30 garage     118
# 24       110306  variation  110306-2018-30  CITROEN  30 garage     118
# 25       110306  variation   110306-2018-7  CITROEN   7 garage     118
# 26       110307  variation  110307-2018-30  CITROEN  30 garage     118
# 27       110307  variation   110307-2018-7  CITROEN   7 garage     118
# 28       110308  variation  110308-2018-30  CITROEN  30 garage     118
# 29       110308  variation   110308-2018-7  CITROEN   7 garage     118
#
#    Attribute 1 name Attribute 1 value(s) Attribute 2 name  \
# 0              anio                 2018           Modelo
# 1              anio                 2018           Modelo
# 2              anio                 2018           Modelo
# 3              anio                 2018           Modelo
# 4              anio                 2018           Modelo
# 5              anio                 2018           Modelo
# 6              anio                 2018           Modelo
# 7              anio                 2018           Modelo
# 8              anio                 2018           Modelo
# 9              anio                 2018           Modelo
# 10             anio                 2018           Modelo
# 11             anio                 2018           Modelo
# 12             anio                 2018           Modelo
# 13             anio                 2018           Modelo
# 14             anio                 2018           Modelo
# 15             anio                 2018           Modelo
# 16             anio                 2018           Modelo
# 17             anio                 2018           Modelo
# 18             anio                 2018           Modelo
# 19             anio                 2018           Modelo
# 20             anio                 2018           Modelo
# 21             anio                 2018           Modelo
# 22             anio                 2018           Modelo
# 23             anio                 2018           Modelo
# 24             anio                 2018           Modelo
# 25             anio                 2018           Modelo
# 26             anio                 2018           Modelo
# 27             anio                 2018           Modelo
# 28             anio                 2018           Modelo
# 29             anio                 2018           Modelo
#
#    Attribute 2 value(s) Attribute 3 name         Attribute 3 value(s)  \
# 0                    A1          Versión                         1.4T
# 1                    A1          Versión                         1.4T
# 2                    Q3          Versión                        1.4 T
# 3                    Q3          Versión                        1.4 T
# 4                    Q3          Versión                  1.4 T 150HP
# 5                    Q3          Versión                  1.4 T 150HP
# 6                    A4          Versión                   2.0 T L/16
# 7                    A4          Versión                   2.0 T L/16
# 8                    Q2          Versión  1.4 T 150HP STRONIC OFFROAD
# 9                    Q2          Versión  1.4 T 150HP STRONIC OFFROAD
# 10                    M          Versión                    5 M SPORT
# 11                    M          Versión                    5 M SPORT
# 12             BERLINGO          Versión                  FURGON 1.4I
# 13             BERLINGO          Versión                  FURGON 1.4I
# 14             BERLINGO          Versión         FURGON 1.4I BUSINESS
# 15             BERLINGO          Versión         FURGON 1.4I BUSINESS
# 16                    C          Versión               3 AIRCROSS 1.6
# 17                    C          Versión               3 AIRCROSS 1.6
# 18                    C          Versión             4 LOUNGE 1.6 THP
# 19                    C          Versión             4 LOUNGE 1.6 THP
# 20                    C          Versión        4 LOUNGE 1.6 THP FEEL
# 21                    C          Versión        4 LOUNGE 1.6 THP FEEL
# 22                    C          Versión        4 LOUNGE 1.6 HDI FEEL
# 23                    C          Versión        4 LOUNGE 1.6 HDI FEEL
# 24                    C          Versión       4 LOUNGE 1.6 THP SHINE
# 25                    C          Versión       4 LOUNGE 1.6 THP SHINE
# 26                    C          Versión       4 PICASSO THP 165 FEEL
# 27                    C          Versión       4 PICASSO THP 165 FEEL
# 28                    C          Versión       4 GRAND PICASSO 1.6HDI
# 29                    C          Versión       4 GRAND PICASSO 1.6HDI
#
#     Regular price  Sale price  In stock?  Published Visibility in catalog  \
# 0               0           0          1          1               visible
# 1               0           0          1          1               visible
# 2               0           0          1          1               visible
# 3               0           0          1          1               visible
# 4               0           0          1          1               visible
# 5               0           0          1          1               visible
# 6               0           0          1          1               visible
# 7               0           0          1          1               visible
# 8               0           0          1          1               visible
# 9               0           0          1          1               visible
# 10              0           0          1          1               visible
# 11              0           0          1          1               visible
# 12              0           0          1          1               visible
# 13              0           0          1          1               visible
# 14              0           0          1          1               visible
# 15              0           0          1          1               visible
# 16              0           0          1          1               visible
# 17              0           0          1          1               visible
# 18              0           0          1          1               visible
# 19              0           0          1          1               visible
# 20              0           0          1          1               visible
# 21              0           0          1          1               visible
# 22              0           0          1          1               visible
# 23              0           0          1          1               visible
# 24              0           0          1          1               visible
# 25              0           0          1          1               visible
# 26              0           0          1          1               visible
# 27              0           0          1          1               visible
# 28              0           0          1          1               visible
# 29              0           0          1          1               visible
#
#     Suma
# 0   1510
# 1   1510
# 2   2400
# 3   2400
# 4   2450
# 5   2450
# 6   2600
# 7   2600
# 8   2400
# 9   2400
# 10  8500
# 11  8500
# 12   590
# 13   590
# 14   630
# 15   630
# 16   825
# 17   825
# 18   800
# 19   800
# 20   845
# 21   845
# 22   865
# 23   865
# 24   930
# 25   930
# 26  1450
# 27  1450
# 28  1600
# 29  1600

# %%
matriz_propiedad_excel.to_excel("upload.xlsx",index=False,
             sheet_name='EXP')

# %%
from openpyxl import load_workbook
# new dataframe with same columns
writer = pd.ExcelWriter('upload.xlsx', engine='openpyxl')
# try to open an existing workbookpload
writer.book = load_workbook('upload.xlsx')
# copy existing sheets
writer.sheets = dict((ws.title, ws) for ws in writer.book.worksheets)
# read existing file
reader = pd.read_excel('upload.xlsx')
# write out the new sheet
final_costo.to_excel(writer,index=False,header=False,startrow=len(reader)+1,sheet_name='EXP')
writer.close()
